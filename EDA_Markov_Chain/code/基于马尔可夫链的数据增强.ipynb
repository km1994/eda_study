# %% [markdown]
# # 基于马尔可夫链的数据增强
#
# [NLP极简数据增强资料](https://mp.weixin.qq.com/s?__biz=MzI4MDYzNzg4Mw==&mid=2247490495&idx=5&sn=a7437ee2be71d03037f5d973ccb1a3bd&chksm=ebb4236bdcc3aa7d277eca08fab7d3020103d1047620f4805dbb237be3812c785e5daf340658&mpshare=1&scene=22&srcid=&sharer_sharetime=1572928152692&sharer_shareid=da84f0d2d31380d783922b9e26cacfe2#rd)
#
# [NLP极简数据增强源码](https://github.com/leerumor/nlpcab)

# %%
import numpy as np
import random
import jieba
import pandas as pd
from collections import Counter
random.seed(44)

# %%
def toutiao_markov_augmentation(in_file, out_file):
    dat = pd.read_csv(in_file, sep="\t",encoding='utf8', header=None, names=["classname","title"])
    print(f"num train samples: {len(dat)}")
    dat = dat
    lbl2cls = {str(y[0]):x for x,y in enumerate(dat[["classname"]].drop_duplicates().values)}
    print(lbl2cls)
    print(f"num class: {len(lbl2cls)}")
    x_train, y_train = dat["title"].apply(lambda x: " ".join([w for w in jieba.cut(x, cut_all=False)]).strip()), dat["classname"]
    c = Counter(x_train.apply(lambda x: len(x.split())))
    lenghts = np.asarray(list(c.keys()))
    freq = np.asarray(list(c.values()))
    freq = freq/freq.sum()
    new_corpus, new_labels = Generator(x_train, y_train, lenghts, freq, 10, concat=False, seed=33)
    print(new_corpus[0:5])
    print(new_labels[0:5])
    with open(file=out_file,encoding="utf8",mode= "w") as fout:
        for i in range(len(new_corpus)):
            print("new_labels[i]:{0}".format(new_labels[i]))
            print("lbl2cls[new_labels[i]]:{0}".format(lbl2cls[new_labels[i]]))
            fout.write("\t".join([new_labels[i], new_corpus[i]])+"\n")
    print(f"save output to {out_file}")

### DEFINE MARKOV CHAIN GENERATOR ###

def build_chain(texts):
    
    index = 1
    chain = {}
    
    for text in texts:
        
        text = text.split()
        for word in text[index:]:
            key = text[index-1]
            if key in chain:
                chain[key].append(word)
            else:
                chain[key] = [word]
            index += 1
        
        index = 1
    
    return chain

def create_sentence(chain, lenght, seed):
    
    np.random.seed(seed)
    
    start = random.choice(list(chain.keys()))
    text = [start]

    while len(text) < lenght:
        try:
            after = random.choice(chain[start])
            start = after
            text.append(after)
        except: #end of the sentence
            #text.append('.')
            start = random.choice(list(chain.keys()))
    
    return ' '.join(text)

def Generator(x_train, y_train, lenghts, freq, rep, concat=False, seed=33):
    
    np.random.seed(seed)
    
    new_corpus, new_labels = [], []
    
    for i,lab in enumerate(np.unique(y_train)):

        selected = x_train[y_train == lab]
        chain = build_chain(selected)

        sentences = []
        for i in range(rep):
            lenght = int(np.random.choice(lenghts, 1, p=freq))
            sentences.append(create_sentence(chain, lenght, seed))

        new_corpus.extend(sentences)
        new_labels.extend([lab]*rep)
    
    if concat:
        return list(x_train) + new_corpus, list(y_train) + new_labels
    
    return new_corpus, new_labels

# %%
def main():
    toutiao_markov_augmentation("F:\\document\\datasets\\nlpData\\text_classifier_data\\THUCNews_ch\\cnews.train.txt", "aug_train.txt")
    print("done.")

# %%
main()
# Out:
# num train samples: 50000
# {'体育': 0, '娱乐': 1, '家居': 2, '房产': 3, '教育': 4, '时尚': 5, '时政': 6, '游戏': 7, '科技': 8, '财经': 9}
# num class: 10
# ['今非昔比 。 ” 。 本 周末 时 ， 阿联 自己 的 塞 弗罗 曼 的 儿子 来 证明 自己 也 没有 第三种 得分 … 丹佛 高原 ， 今天 就是 这种 全面 表现 无愧 第一 中锋 受 待遇 ， 双方 战成 49 - 莫雷 和 李冬生 和 王 吉恩 报道 ， 所以 他 都 在 2011 - 约翰逊 和 贾马尔 - 埃文斯 ， “ 大 前锋 拉里 - 马丁 今天 还 可能 要求 很 好 机会 打败 爱国者 队 的 采访 时 表示 ： 雷 - 邓肯 中投 偏出 ， 他们 何时能 到头 了 一些 伟大 的 。 可以 看出 在 三分 。 ” 吉尔伯特 - 21 分 ， 麦克戴斯 13 - 布鲁克斯 伤停 之后 ， 森林狼 。 如今 的 祭旗 ， ” 格里芬 是 雄鹿 和 热情 ， 他 说 两句 了 两次 罚球 17 分 ， 球队 ， 华仔 失去 悬念 ， 本周 升幅 最大 的 数据 媲美 的 肖恩 - 刘易斯 埋伏 的 真实 意义 。 湖人队 中 ， 这样 的 复健 运动 中 所 希望 。 而 以 62 - 戈登 三分 。 骑士 多项 队史 新高 。 公牛 被 判罚 毫 无疑 都 觉得 很 高兴 过头 了 。 [ 直播 中 得到 19 分 ， 但是 火箭 对 球队 才能 在 西部 前八 。 最近 三场 比赛 后 双手 暴扣 ， 锁定 胜局 。 至于 小 詹姆斯 这样 的 ， 沃尔 自己 出手 仍然 领先 。 黄蜂 等 筹码 的 一笔 超级 球星 德隆 特 、 灰熊 的 光彩 相当 罕见 公开批评 全队 第四 好 地 冲向 篮筐 上 双 20 分 ， 会 在 土耳其 联赛 第一轮 的 ， 巴蒂尔 在 击败 的 控球 ， 结果 ， 我们 认识 ， 高居 全 联盟 顶级 球员 ； 快船 能够 挖 来 了 。 吕晓明 在 盐湖城 等等 。 12 日 ( 韦德 和 火箭 最 重要 的 卫士 or 阿伦 因为 上门 求购 新浪 体育讯 北京 时间 11 月 7 篮板 ， 怎么 说 ， 以 102 击败 湖人 双 的 成功率 ， 对 吧 。 可 随后 内线 球员 如此 ， 加时赛 ， 排 在 季后赛 后 ， 姚明 的 时候 ， 就算 在 山猫 先发 后场 双核 。 这 很 体面 ， 奇才 着实 不低 ： 黑马 传奇 摇篮 。 埃里克 - 普拉达 率先 打探 的 防守 端 得到 5 点 ， 老鹰队 面前 ， 对阵 奥兰多 人 痛心 。 异地 再战 ， 正是 全场 出手 4 ) 新浪 体育讯 火箭 带来 本场 比赛 剩下 2 月 12 个 篮板 ， “ 如果 打成 ， 科比 对 我 那 我 的 得分手 。 菲尔 - 辛里奇 、 布鲁克斯 还 没过 50% ， 他 可以 看到 ， 昨天晚上 ， 有 后来居上 ， 被 看好 东部 排名 东部 也 在 剩下 55 秒 时 替补 ， 塔 比特 拥有 稳定 的 姚明 的 爆发 出 ， 从 不会 给 后场 篮板 ， 根据 媒体 渲染 、 琼斯 、 马克 希尔 和 马克 说道 ： 第二节 比赛 的 第一次 运动战 中 自己 的 扣篮 时 以 102 保持 职业 球员 之一 ， 投篮 命中 还 包括 最后 时刻 投 9 分钟 ， 斯科特 一再表示 他 的 时候 怎么办 ？ ( 19 平 ， 他 的 争夺 总冠军 。 ” 出现 不少 人 扣 在 热火 在 交易 来到 了 。 我们 现在 仅仅 剩下 苏伟 篮下 杀伤 。 当然 ， 连 砍 高分 。 由于 实力 ， 很快 ， 他 是 一个 弱 ， 西装革履 地 防守 策略 就是 7 个 好 的 男篮 新闻官 跑 轰 大队 ， 他 成为 国字号 球员 经过 手术 中 却 让 这样 一支 优秀 的 处理 完宝碧后 事后 ， 上篮 得手 ， 这 都 是 你 的 。 第一节 开始 兜售 汤普森 篮下 的 事 之前 的 三位 老将 鼓掌 ， 奇才 率先 助攻 率 马刺 时 ， 其余 6 秒钟 ， 那 两次 惜败 快船 开始 高喊 “ 中锋 。 据 内幕 没 反应 是 到 巴丁 格 替换 了 对方 犯规 困境 中 ， 我们 还 坚持 打 绿衫 军 的 得分 上 ， 莱利 就 将 比分 追成 69 落后 6 分 23 英尺 投篮 ， 但 为时已晚 。 至于 尼克 - 斯科特 再次 谢谢 ” 伤病 困扰 着 嘣 出 患上 重感冒 ， 不过 复出 。 ( 布鲁克斯 ， 小 交易 D - 海耶斯 受伤 ， 作为 次轮秀 的 准备 ， 火箭 首发 与否 的 磨合 时期 的 ， 帮助 佛山 队 和 其他 将士 从 2 个 篮板 的 轮转 阵容 ， 球队 ， 而 去 任何 事情 ， 海耶斯 等 的 高度 增加 火箭 更衣室 的 表现 低迷 也 差不多 一年 进入 了 23 分 7 个 ， 此后 也 主场 击败 公牛 继续 保持 进攻 的 球员 们 也 更 倚重 外线 是 角色 是 支 可能 去 争取 在 优先权 让给 风生水 起 全队 第二 得分手 勒夫 、 阵容 ， 康利 身上 扔 10 月 7 中 唯一 的 不足 9% 的 原因 。 首先 要 到', '但费根 如此 近 40 领先 。 ” 主力 问号 。 拜纳姆 的 纪录 。 投篮不中 ， “ 说谎 的 电视频道 太 多 ， 对于 这支 火箭队 来说 无疑 伦比 的 三分球 ， 勒夫 得到 19 分 和 篮网 签下 一份 子 ， 也 不 沾 ， 拿到 116.1 分 ， 过去 三场 胜利 。 下半场 ， “ 大 前锋 两个 压哨 三分 不 讲 了 警钟 。 官网 报道 ， 加索尔 虽然 紫金 军团 一 菜鸟 球员 ， 但是 球队 三方 甚至 首节 也 是 个 盖帽 ！ 火箭 ： 毕比 换下 ， 则 是 指 不远处 山东 本赛季 也 拥有 竞争 是 他们 做到 相同 ， 已经 有 什么 便宜 ， 张庆鹏 和 影星 之一 。 对阵 卫冕冠军 成功 。 他们 落后 。 火箭 本 - 加索尔 空中 接力 和 查克 - 35 分钟 得到 12 负 。 然后 重新 组织 能力 ： “ 我们 也 一直 有 天赋 的 “ 屠龙 软硬兼施 也 就 会 碰到 了 同年 NFL 球员 的 时候 我 还 以 81 - 91 比 其他人 没有 涉及 了 一条 船上 的 很 沮丧 新浪 体育讯 北京 时间 1 投 丢 93 - 哈雷森 和 山猫 无功而返 。 小斯 和 队友 间 流露 着 球迷 突然 发飙 ， 这 家伙 ， 他 将 比分 反超 ， 更 大 Z 首发 后 ， 热火 由守 转攻 的 管理层 不 刻苦 ， 老杜 有时候 需要 一个 疑似 压哨 球 ， 今天 洛瑞 打出 一个 三分球 命中率 是 有 参与感 。 僵持 了 说明 问题 ， ” 沃尔 在 热火 凭借着 巴图姆 ， 身为 大 反击 更为 要命 的 非常 不满 — 而查 特曼 — — — — 奇才 本有 完美 开局 让 丹佛 ， 以 112 ∶ 101 - 麦克 罗伯茨 。 那时 我 小 加索尔 虽然 最终 本 节 唯一 能 有 球员 树立 起 投篮 ， 裁判 判罚 的 两双 ， 湖人 的 悍将 克里 森 拿下 22 秒 。 2011 年 期间 表现 ， 在 对抗 ， 罚球 ) 七 连胜 之师 ， 没 中 ， 笔者 认为 ： 0 ， 此前 在 比赛 陷入 “ 翻身 新浪 体育讯 北京 时间 1 个 篮板 ， 但 猛龙 一起 。 本 节 还有 几何 ， 由于 昨天 在 丰田 中心 直接对话 ， 湖人 、 5 成 定势 筹码 ， 而 上个月 的 。 有 7 篮板 和 新疆 领先 4 分 21 分 ， 韦德 16 投仅 7 点半 开始 退出 联赛 第一 凯尔特人 。 他 今天 投篮 得手 ， 表现 ， 火箭 ， 斯科拉 说道 的 地方 了 德维恩 - 哈里斯 连续 两场 之后 ) 消息 ， 症结 就 跑 过 ， 一直 是 缺席 奥运会 的 进攻 球队 永远都是 王 ) 平时 爱看 足球 项目 ， 他 仍然 将球 打进 之后 将 差距 很快 掌控 全场 比赛 方式 打球 状态 。 果不其然 ， 奥多姆 和 上 的 表现 ， 安东尼 的 ， 化学反应 新浪 体育讯 北京 时间 12 月 15 胜出 几率 有 球迷 们 的 最大 的 比赛 的 机会 。 没有 假期 去 饭店 服务员 小姑娘 到 的 前景 ， 此后 两节 艰难 ， 直接 导致 连胜 ， 也 不 一样 ， 他们 场均 13 分 和 赛后 ESPN 消息 ， 更 多 打 8 次 盖帽 1 投 4 次 ， 为此 抓狂 的 比赛 里 - 马丁 上篮 得手 。 这 好好 防守 脚步 扎实 低调 表示 强烈 渴望 在 更衣室 里 似乎 都 是 3 罚 2 个 篮板 ， 值得 关注 的 创伤 ， 他们 需要 这样 的 是 这样 的 地位 ？ 克里斯 - 塔 比特 的 成绩 就 只有 37.4% ， 但 伤病 或许 才 会 在 文末 发布 声明 ， 无论是 进攻 状态 ， 虽然 已经 证明 了 ， 其 官方网站 微博 ， 詹姆斯 的 打球 。 击败 绿衫 军狂 胜 0 的 。 布鲁克斯 的 场 常规赛 的 计划 的 球队 老板 的 防守 中 ， “ 休斯敦 火箭 球员 的 ， 因为 感冒 ， 辽宁队 的 。 虽然 对手 阵容 ， 吃 到 正处级 ， 令人 惊艳 表现 很 足 。 安东尼 成为 数据 稳中有升 ， 则 是 巨星 感到 不 开心 的 那种 窘境 ， 继 奥斯卡 - 刘易斯 本场 比赛 中 ， 甚至 没有 放弃 奖项 。 赛后 ， 不断 的 王大勇 本场 比赛 得分 的 ...
# ['体育', '体育', '体育', '体育', '体育']
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:体育
# lbl2cls[new_labels[i]]:0
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:娱乐
# lbl2cls[new_labels[i]]:1
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:家居
# lbl2cls[new_labels[i]]:2
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:房产
# lbl2cls[new_labels[i]]:3
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:教育
# lbl2cls[new_labels[i]]:4
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时尚
# lbl2cls[new_labels[i]]:5
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:时政
# lbl2cls[new_labels[i]]:6
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:游戏
# lbl2cls[new_labels[i]]:7
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:科技
# lbl2cls[new_labels[i]]:8
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# new_labels[i]:财经
# lbl2cls[new_labels[i]]:9
# save output to aug_train.txt
# done.
